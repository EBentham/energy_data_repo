# %% [markdown]
# # Gemini's formula for a GAM:

# %% [markdown]
# $$ \log(\text{Demand}_t) = \alpha + s_1(\text{Temperature}_t) + s_2(\text{WindSpeed}_t) + s_3(\text{HourOfDay}_t) + s_4(\text{DayOfYear}_t) + f(\text{DayOfWeek}_t) + \epsilon_t $$

# %% [markdown]
# # Asking ChatGPT if this is industrry standard approach:

# %% [raw]
# https://chatgpt.com/c/689e5d60-1eb4-832a-b2ce-71007bdcbbcb

# %% [markdown]
# ![image.png](attachment:image.png)
